# %%
import pandas as pd

import numpy as np
import json
import geog
import shapely.geometry
import geopandas as gpd
import folium
from shapely import wkt, geometry
import json
from pprint import pprint
from folium import plugins

# %%
data = pd.read_csv('listings_cleaned.csv', index_col = 'id')

# %%
cta_json = gpd.read_file('cta_entrances.geojson')

# %%
import random 
random_row = random.randint(0,len(data))
random_row
# Out:
# 5205

# %%
base_long = data.longitude.iloc[random_row]
base_lat = data.latitude.iloc[random_row]

# %%
p = shapely.geometry.Point([base_long,base_lat])
n_points = 100
d = 1000  # meters
angles = np.linspace(0, 360, n_points)
polygon = geog.propagate(p, angles, d)
wkt_str = shapely.geometry.Polygon(polygon).wkt
#wkt_str = json.dumps(shapely.geometry.mapping(shapely.geometry.Polygon(polygon)))
#print(shapely.geometry.mapping(shapely.geometry.Polygon(polygon)))
aoi_geom = wkt.loads(wkt_str)

# %%
poly = shapely.geometry.Polygon(polygon)

# %%
aoi_coords = list(aoi_geom.exterior.coords) # get coords from exterior ring
aoi_coords = [(y,x) for x,y in aoi_coords] # swap (x,y) to (y,x). Really leaflet?!
aoi_centroid = aoi_geom.centroid # Kreuzberg center for map center

# %%
cta_json
# Out:
#                   name agency                                      line  \
# 0                 18th    CTA                                 Pink Line
# 1          35th/Archer    CTA                               Orange Line
# 2        95th-Dan Ryan    CTA                                  Red Line
# 3         Adams/Wabash    CTA  Brown, Purple, Orange, Pink, Green Lines
# 4              Addison    CTA                                 Blue Line
# ..                 ...    ...                                       ...
# 376   Washington/Wells    CTA  Brown, Purple, Orange, Pink, Green Lines
# 377  Washington/Wabash    CTA  Brown, Purple, Orange, Pink, Green Lines
# 378  Washington/Wabash    CTA  Brown, Purple, Orange, Pink, Green Lines
# 379  Washington/Wabash    CTA  Brown, Purple, Orange, Pink, Green Lines
# 380  Washington/Wabash    CTA  Brown, Purple, Orange, Pink, Green Lines
#
#                        geometry
# 0    POINT (-87.66914 41.85785)
# 1    POINT (-87.68063 41.82927)
# 2    POINT (-87.62441 41.72273)
# 3    POINT (-87.62600 41.87971)
# 4    POINT (-87.71841 41.94660)
# ..                          ...
# 376  POINT (-87.63378 41.88299)
# 377  POINT (-87.62609 41.88231)
# 378  POINT (-87.62626 41.88232)
# 379  POINT (-87.62609 41.88297)
# 380  POINT (-87.62632 41.88296)
#
# [381 rows x 4 columns]

# %%
m = folium.Map(tiles='OpenStreetMap',location=(aoi_centroid.y, aoi_centroid.x), zoom_start=15)

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
icon = folium.map.Icon(color='darkblue',
                        icon_color='#ade8f4',
                        icon='bed', # fetches font-awesome.io symbols
                        prefix='fa')
#popup = "<strong>{0}</strong><br>Accommodates: {1}<br>Bathrooms: {2}<br>Price: {3}<br>Link: {4}".format(data.loc[data.iloc[random_row].name]['name'],data.loc[data.iloc[random_row].name]['accommodates'], data_full.loc[data.iloc[random_row].name]['bathrooms'],data_full.loc[data.iloc[random_row].name]['price'],data_full.loc[data.iloc[random_row].name]['listing_url'])
folium.map.Marker([base_lat,base_long], icon=icon, ).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
folium.vector_layers.Polygon(aoi_coords,
                                     color='#FCA311',
                                     fill_color='#DEB841',
                                    fill_opacity=0.05,
                                     weight=3).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
icon_out = folium.map.Icon(color='red',
                            icon_color='#FFFFFF',
                            icon='subway', # fetches font-awesome.io symbols
                            prefix='fa')
icon_in = folium.map.Icon(color='green',
                            icon_color='#FFFFFF',
                            icon='subway', # fetches font-awesome.io symbols
                            prefix='fa')

#folium.map.Marker([cta_json['geometry'][0].y, cta_json['geometry'][0].x], icon=icon).add_to(m)

# %%
# from folium.plugins import MarkerCluster
# stations = plugins.MarkerCluster().add_to(m)

# %%
# for name, point, line in zip(cta_json['name'], cta_json['geometry'], cta_json['line']):
#     if point.within(poly):
#         folium.Marker([point.y, point.x], popup= "<strong>{0}</strong><br>{1}<br>".format(name, line),
#                       icon = folium.Icon(color='green',
#                                 icon_color='#FFFFFF',
#                                 icon='subway', # fetches font-awesome.io symbols
#                                 prefix='fa')).add_to(m)
#     else:
#         folium.CircleMarker(
#             [point.y, point.x],
#             radius=2,
#             popup = "<strong>{0}</strong><br>{1}<br>".format(name, line),
#             color='red',
#             fill=True,
#             fill_opacity=0.7
#             ).add_to(m)
        
        
        
        
# #         folium.Marker([point.y, point.x], popup= "<strong>{0}</strong><br>{1}<br>".format(name, line),
# #                       icon = folium.Icon(color='red',
# #                                 icon_color='#FFFFFF',
# #                                 icon='subway', # fetches font-awesome.io symbols
# #                                 prefix='fa')).add_to(m)

# %%
# m

# %%
from openrouteservice import client, places
api_key='5b3ce3597851110001cf6248f4a7fee5db334593bc67406f86071778'
clnt = client.Client(key=api_key)
routes = {}
times = []
list_loc = [[base_long,base_lat]]
n = 0 
for name, point, line, x in zip(cta_json['name'], cta_json['geometry'], cta_json['line'], range(len(cta_json))):
    if point.within(poly):
        folium.Marker([point.y, point.x], popup= "<strong>{0}</strong><br>{1}<br>".format(name, line),
                      icon = folium.Icon(color='green',
                                icon_color='#FFFFFF',
                                icon='subway', # fetches font-awesome.io symbols
                                prefix='fa')).add_to(m)
        cta_loc = [[point.x,point.y]] 
        route_coords =  list_loc + cta_loc  
        request = {'coordinates': route_coords,
           'profile': 'foot-walking',
           'geometry': 'true',
           'format_out': 'geojson'}
        route = clnt.directions(**request)
        routes[n] = route
        times.append(route['features'][0]['properties']['summary']['duration'])
        n += 1
    else:
        folium.CircleMarker(
            [point.y, point.x],
            radius=3,
            popup = "<strong>{0}</strong><br>{1}<br>".format(name, line),
            color='red',
            fill=True,
            fill_opacity=0.7
            ).add_to(m)

# %%
#routes[0]['features'][0]['properties']['summary']

# %%
times
# Out:
# [578.7,
#  377.9,
#  374.0,
#  347.2,
#  354.6,
#  729.4,
#  743.9,
#  770.0,
#  754.3,
#  675.0,
#  654.3,
#  654.1,
#  605.5,
#  576.7,
#  582.6,
#  592.8,
#  628.3,
#  188.7,
#  227.1,
#  233.2,
#  287.7,
#  641.9,
#  661.5]

# %%
#m.add_child(folium.map.LayerControl())

# %%
def style_function(color):
    return lambda feature: dict(color=color,
                              weight=7,
                              opacity=1)

# %%
for x in routes[0]['features'][0]['properties']['summary']:
    print(str(x))
# Out:
# distance
# duration

# %%
routes[0]['features'][0]['properties']['summary']
# Out:
# {'distance': 803.7, 'duration': 578.7}

# %%
fields=[["summary"][0]]

# %%
tooltip = folium.features.GeoJsonTooltip(
    fields=(["summary"]),
    aliases=["Route Distance in Meters and Duration of the route (yet in seconds): "],
    sticky=False,
    labels=True,
    style="""
        background-color: #F0EFEF;
        border: 2px solid black;
        border-radius: 3px;
        box-shadow: 3px;
    """,
    max_width=800,
)

# %%
#tooltip2 = folium.map.Tooltip(("<strong>Route Distance in Meters:{0}</strong><br>Duration of the route{1}<br>".format(routes[fastest]['features'][0]['properties']['summary']['duration'], routes[fastest]['features'][0]['properties']['summary']['distance'])))

# %%
def route_plot(routes_matrix):
    for x in routes:
        if routes[x]['features'][0]['properties']['summary']['duration'] == min(times):
            print(True)
            fastest = x
            print(fastest)
        else:
            folium.features.GeoJson(data=routes[x],
                            name='Route' + str(x),
                            style_function= style_function('#DEB841'),
                           overlay=False).add_to(m)
            #m.add_child(folium.map.LayerControl())
    if fastest or fastest == 0:
        print(True)
        folium.features.GeoJson(data=routes[fastest],
                            name='Route' + str(fastest),
                            style_function= style_function('#0ead69'),
                            tooltip = folium.map.Tooltip(("<strong>Route Distance in Meters: {0}</strong><br>Duration of the route: {1}<br>".format(routes[fastest]['features'][0]['properties']['summary']['duration'], routes[fastest]['features'][0]['properties']['summary']['distance']))),
                           overlay=True).add_to(m)
        #m.add_child(folium.map.LayerControl())
        return m
    else: 
        return m

# %%
route_plot(routes)
# Out:
# True
# 17
# True
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# for x in routes:
#     if routes[x]['features'][0]['properties']['summary']['duration'] == min(times):
#         print(True)
#         folium.features.GeoJson(data=routes[x],
#                         name='Route' + str(x),
#                         style_function= style_function('#0ead69'),
#                        overlay=True).add_to(m)
#     else:
#         folium.features.GeoJson(data=routes[x],
#                         name='Route' + str(x),
#                         style_function= style_function('#DEB841'),
#                        overlay=False).add_to(m)
# #m.add_child(folium.map.LayerControl())
# m

# %%
# for count, route in enumerate(routes):
#     folium.features.GeoJson(data=routes[count],
#                             name='Route' + str(x),
#                             style_function= style_function('#0ead69'),
#                            overlay=True).add_to(m)

# %%
for station in range(len(cta_json)):
#for station in range(5):
    #if cta_json['geometry'][station].within(poly) == True:
        #print(station)
    folium.Marker([cta_json['geometry'][station].y, cta_json['geometry'][station].x], 
                          icon=icon_in
                         ).add_to(m)
    
#     else:
#         #print(station)
#         folium.map.Marker([cta_json['geometry'][station].y, cta_json['geometry'][station].x], 
#                           icon=icon_out
#                          ).add_to(m)
# m.add_child(folium.map.LayerControl())

# %%
for station in cta_json:
    if station['geometry'].within(poly):
        print(True)
#         folium.map.Marker([station['geometry'].y, station['geometry'].x], 
#                           icon=icon_in
#                          ).add_to(m)
#     else:
#         folium.map.Marker([station['geometry'].y, station['geometry'].x], 
#                           icon=icon_out
#                          ).add_to(m)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-1342-e1b3b4278e73> in <module>
#       1 for station in cta_json:
# ----> 2     if station['geometry'].within(poly):
#       3         print(True)
#       4 #         folium.map.Marker([station['geometry'].y, station['geometry'].x],
#       5 #                           icon=icon_in
#
# TypeError: string indices must be integers

# %%
m

# %%
cta_json['geometry'][0].x

# %%
# def style_function(color):
#     return lambda feature: dict(color=color,
#                               weight=7,
#                               opacity=1)

# %%
style_function = lambda x: {'fillColor': '#0ead69' if
                          x['geometry'].within(poly) else
                            '#DEB841'}

# %%
for x in cta_json:
    if x['geometry'].within(poly):
        folium.GeoJson(
            cta_json,
            name='geojson'
).add_to(m)

# %%
folium.GeoJson(
    cta_json,
    #style_function = style_function,
    name='geojson'
).add_to(m)

# %%
m
