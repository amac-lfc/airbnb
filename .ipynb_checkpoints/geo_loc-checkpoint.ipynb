# %%
import pandas as pd
### packages for geo data 
import requests
import osmnx as ox
import re
import openrouteservice as ors
import time
import numpy as np

# %%
#url = 'https://raw.githubusercontent.com/amac-lfc/airbnb/master/listings_cleaned.csv?token=AHV2IBERPQTIJA36632SDGC7A6YOW'
data = pd.read_csv('sample_30.csv',index_col=['id'])

# %%
ox.config(log_console=True, use_cache=True)

# %%
tags = {'amenity':['restaurant', 'bar', 'cafe'],
       'railway': 'subway'}
test = ox.pois_from_point(point=(data.latitude.iloc[0],data.longitude.iloc[0]), dist=1000, tags=tags)
test.head()
# Out:
# C:\Users\sgevo\Anaconda3\envs\ox\lib\site-packages\osmnx\pois.py:370: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   gdf = gdf.loc[gdf["geometry"].centroid.within(polygon)]
#                osmid                    geometry addr:city addr:country  \
# 347159885  347159885  POINT (-87.63487 41.91128)   Chicago           US
# 347160446  347160446  POINT (-87.63838 41.91272)   Chicago          NaN
# 463772258  463772258  POINT (-87.65681 41.92157)       NaN          NaN
# 477087140  477087140  POINT (-87.64610 41.92339)   Chicago          NaN
# 477087270  477087270  POINT (-87.65297 41.92165)   Chicago          NaN
#
#           addr:housenumber addr:postcode addr:state            addr:street  \
# 347159885              210         60610         IL      West North Avenue
# 347160446             1655         60614         IL  North Sedgwick Street
# 463772258              NaN           NaN        NaN                    NaN
# 477087140             2274         60614         IL   North Lincoln Avenue
# 477087270              949         60614         IL    West Webster Avenue
#
#               amenity      brand  ... gauge voltage frequency cta:objectid  \
# 347159885        cafe  Starbucks  ...   NaN     NaN       NaN          NaN
# 347160446  restaurant        NaN  ...   NaN     NaN       NaN          NaN
# 463772258  restaurant        NaN  ...   NaN     NaN       NaN          NaN
# 477087140         bar        NaN  ...   NaN     NaN       NaN          NaN
# 477087270         bar        NaN  ...   NaN     NaN       NaN          NaN
#
#           cta:segmentid tunnel service building:levels chicago:building_id  \
# 347159885           NaN    NaN     NaN             NaN                 NaN
# 347160446           NaN    NaN     NaN             NaN                 NaN
# 463772258           NaN    NaN     NaN             NaN                 NaN
# 477087140           NaN    NaN     NaN             NaN                 NaN
# 477087270           NaN    NaN     NaN             NaN                 NaN
#
#           smoking
# 347159885     NaN
# 347160446     NaN
# 463772258     NaN
# 477087140     NaN
# 477087270     NaN
#
# [5 rows x 59 columns]

# %%
test.columns
# Out:
# Index(['osmid', 'geometry', 'addr:city', 'addr:country', 'addr:housenumber',
#        'addr:postcode', 'addr:state', 'addr:street', 'amenity', 'brand',
#        'brand:wikidata', 'brand:wikipedia', 'cuisine', 'entrance', 'name',
#        'official_name', 'takeaway', 'element_type', 'opening_hours', 'phone',
#        'website', 'railway', 'network', 'operator', 'public_transport',
#        'subway', 'addr:housename', 'wheelchair', 'source', 'addr:street:name',
#        'addr:street:prefix', 'addr:street:type', 'delivery', 'wikidata',
#        'building', 'addr:unit', 'outdoor_seating', 'email', 'internet_access',
#        'wikipedia', 'alcohol', 'diet:vegetarian', 'nodes', 'bridge', 'layer',
#        'level', 'old_name', 'oneway', 'electrified', 'gauge', 'voltage',
#        'frequency', 'cta:objectid', 'cta:segmentid', 'tunnel', 'service',
#        'building:levels', 'chicago:building_id', 'smoking'],
#       dtype='object')

# %%
test.amenity.dropna().value_counts()
# Out:
# restaurant    103
# bar            42
# cafe           23
# Name: amenity, dtype: int64

# %%
len(test[test['amenity']=='restaurant'].dropna(axis=1, how='any'))
# Out:
# 103

# %%
client = ors.Client(key='5b3ce3597851110001cf6248fb1ecfcd8ab8422b93b5dd978d83e93e')

# %%
trains = test[test['subway'] == 'yes'].dropna(axis=1, how='any')
trains
# Out:
#                  osmid                    geometry            name  \
# 739322024    739322024  POINT (-87.65256 41.91797)        Armitage
# 739322025    739322025  POINT (-87.65268 41.91796)        Armitage
# 2012780408  2012780408  POINT (-87.63886 41.91041)        Sedgwick
# 2012780433  2012780433  POINT (-87.63885 41.91039)        Sedgwick
# 2039094535  2039094535  POINT (-87.64934 41.91085)  North/Clybourn
# 2368694141  2368694141  POINT (-87.64942 41.91078)  North/Clybourn
#
#            element_type railway network                   operator  \
# 739322024          node    stop     CTA  Chicago Transit Authority
# 739322025          node    stop     CTA  Chicago Transit Authority
# 2012780408         node    stop     CTA  Chicago Transit Authority
# 2012780433         node    stop     CTA  Chicago Transit Authority
# 2039094535         node    stop     CTA  Chicago Transit Authority
# 2368694141         node    stop     CTA  Chicago Transit Authority
#
#            public_transport subway
# 739322024     stop_position    yes
# 739322025     stop_position    yes
# 2012780408    stop_position    yes
# 2012780433    stop_position    yes
# 2039094535    stop_position    yes
# 2368694141    stop_position    yes

# %%
len(trains)
# Out:
# 6

# %%
loc_str = str(trains.geometry.iloc[0])
import re
loc_num = re.sub("[^0-9,^.,^ ,-]", "", loc_str).lstrip().split(' ')
for i in range(len(loc_num)): 
    loc_num[i] = float(loc_num[i]) 
loc_num
# Out:
# [-87.652561, 41.917966]

# %%
coordinates = [[data.longitude.iloc[0],data.latitude.iloc[0]]]
coordinates.append(loc_num)

# %%
coordinates
# Out:
# [[-87.64602, 41.91595], [-87.652561, 41.917966]]

# %%
matrix = client.distance_matrix(
    locations=coordinates,
    profile='foot-walking',
    metrics=['distance', 'duration'],
    validate=False,
)

# %%
print("Durations in secs: {}\n".format(matrix['durations']))
print("Distances in m: {}".format(matrix['distances']))
# Out:
# Durations in secs: [[0.0, 663.21], [663.21, 0.0]]
#
# Distances in m: [[0.0, 921.15], [921.15, 0.0]]

# %%
tags_ext = {'amenity':['restaurant', 'bar', 'cafe','university','pub'],
        'railway': 'subway'}
test = ox.pois_from_point(point=(data.loc[33017791].latitude,data.loc[33017791].longitude), dist=1000, tags=tags_ext)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\envs\ox\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 33017791
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-29-3a364c1bf7c5> in <module>
#       1 tags_ext = {'amenity':['restaurant', 'bar', 'cafe','university','pub'],
#       2         'railway': 'subway'}
# ----> 3 test = ox.pois_from_point(point=(data.loc[33017791].latitude,data.loc[33017791].longitude), dist=1000, tags=tags_ext)
#
# ~\Anaconda3\envs\ox\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1766
#    1767             maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1768             return self._getitem_axis(maybe_callable, axis=axis)
#    1769
#    1770     def _is_scalar_access(self, key: Tuple):
#
# ~\Anaconda3\envs\ox\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1963         # fall thru to straight lookup
#    1964         self._validate_key(key, axis)
# -> 1965         return self._get_label(key, axis=axis)
#    1966
#    1967
#
# ~\Anaconda3\envs\ox\lib\site-packages\pandas\core\indexing.py in _get_label(self, label, axis)
#     623             raise IndexingError("no slices here, handle elsewhere")
#     624
# --> 625         return self.obj._xs(label, axis=axis)
#     626
#     627     def _get_loc(self, key: int, axis: int):
#
# ~\Anaconda3\envs\ox\lib\site-packages\pandas\core\generic.py in xs(self, key, axis, level, drop_level)
#    3535             loc, new_index = self.index.get_loc_level(key, drop_level=drop_level)
#    3536         else:
# -> 3537             loc = self.index.get_loc(key)
#    3538
#    3539             if isinstance(loc, np.ndarray):
#
# ~\Anaconda3\envs\ox\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
# -> 2648                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2649         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2650         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 33017791

# %%
test[test['amenity'] == 'bar'].dropna(axis=1, how='any')

# %%
data.loc[33017791].latitude

# %%
sample = data.sample(50)

# %%
def pois_subway(dataset):
    start = time.time()
    tags = {'railway': 'subway'}
    cta = []
    pois_subway.data = dataset
    for x in range(len(pois_subway.data)):
        pois_subway.temp = ox.pois_from_point(point=(pois_subway.data.latitude.iloc[x],pois_subway.data.longitude.iloc[x]), dist=1000, tags=tags)  
        if 'subway' in pois_subway.temp:
            train = pois_subway.temp[pois_subway.temp['subway'] == 'yes'].dropna(axis=1, how='any')
            cta.append((len(train['name'].unique())))
        else:
            pois_subway.temp = ox.pois_from_point(point=(pois_subway.data.latitude.iloc[x],pois_subway.data.longitude.iloc[x]), dist=5000, tags=tags) 
            train = pois_subway.temp[pois_subway.temp['subway'] == 'yes'].dropna(axis=1, how='any')
            cta.append((len(train['name'].unique())))
    #print(len(restaurants))
    pois_subway.data['CTA'] = cta
    end = time.time()
    print(end - start)
    return pois_subway.data
    return pois_subway.temp

# %%
pois_subway(data)
# Out:
# 10.052088737487793
#           host_listings_count  latitude  longitude  accommodates  bathrooms  \
# id
# 34840808                    1  41.91595  -87.64602             2        1.0
# 17859080                    4  41.95453  -87.67557            10        2.0
# 12201564                    2  41.93444  -87.67293             8        4.5
# 32738124                   38  41.97321  -87.65485             4        1.0
# 29516508                    8  41.84919  -87.70031             4        1.0
# 20679988                    1  41.95405  -87.67771             6        1.0
# 30820481                    4  41.95197  -87.65862            16        5.0
# 26813241                    1  41.99674  -87.66304             2        1.0
# 6953009                     1  41.90603  -87.67556             4        1.0
# 35088121                    4  41.78378  -87.59697             2        1.0
# 37628621                  769  41.87187  -87.62434             2        1.0
# 9384935                     5  41.94786  -87.66014             6        1.0
# 38905198                    6  41.87131  -87.69432             8        2.0
# 24371533                  769  41.88429  -87.66017             4        2.0
# 40929961                    7  41.79603  -87.66166             4        1.0
# 37751583                    2  42.01005  -87.66327             2        1.0
# 29794929                    1  41.90536  -87.69075             6        1.0
# 22582564                    1  41.97733  -87.68869             2        1.0
# 26029969                    1  41.93655  -87.65484             6        2.5
# 16742255                    2  41.88331  -87.63058             6        2.0
# 15216905                    2  41.96538  -87.70073             1        1.0
# 42142600                    0  41.93789  -87.70112             6        1.0
# 40841455                   22  41.91450  -87.71047             4        1.0
# 42948512                    6  41.88510  -87.63368             3        1.0
# 22567457                    1  41.80186  -87.59219             1        1.0
# 23455723                    2  41.84902  -87.63512             2        1.0
# 42076541                   26  41.85466  -87.62572             4        1.0
# 32741575                    3  41.97250  -87.66488             4        1.0
# 30771810                    3  41.94042  -87.67976             6        1.0
# 38192212                    8  41.91238  -87.68051            16        3.0
#
#           price  security_deposit  cleaning_fee  extra_people  minimum_nights  \
# id
# 34840808   85.0               0.0          20.0           0.0               1
# 17859080  516.0               0.0         100.0           0.0               2
# 12201564  450.0            2000.0           0.0           0.0             180
# 32738124  150.0               0.0         100.0          25.0               2
# 29516508   55.0               0.0          25.0           0.0               1
# 20679988  100.0             500.0         137.0          50.0               1
# 30820481  500.0               0.0         200.0          20.0               2
# 26813241  150.0             200.0          88.0          20.0               2
# 6953009   110.0             150.0          50.0          15.0               1
# 35088121   24.0             100.0          49.0          14.0               1
# 37628621  107.0             400.0          70.0           5.0               4
# 9384935   299.0             500.0         150.0           0.0               3
# 38905198  180.0               0.0         260.0           0.0               1
# 24371533  158.0             400.0         128.0           5.0               4
# 40929961   75.0               0.0          52.0          10.0               3
# 37751583   49.0               0.0           0.0          13.0               5
# 29794929  140.0               0.0          50.0           0.0               2
# 22582564   50.0             100.0          20.0          10.0               2
# 26029969  550.0             500.0         130.0          25.0               4
# 16742255  325.0             250.0         120.0          25.0               2
# 15216905   65.0               0.0          75.0           0.0               6
# 42142600   58.0               0.0         150.0           0.0               1
# 40841455  500.0               0.0          50.0           0.0               1
# 42948512  120.0               0.0          75.0           0.0               1
# 22567457   90.0             500.0          75.0          50.0               2
# 23455723  105.0               0.0          40.0          30.0               4
# 42076541  500.0               0.0          75.0           0.0               1
# 32741575   52.0               0.0          65.0           0.0               3
# 30771810  125.0            1500.0          95.0          30.0               1
# 38192212  399.0             600.0         150.0           0.0               1
#
#           maximum_nights  maximum_minimum_nights  minimum_maximum_nights  \
# id
# 34840808               7                       2                       7
# 17859080            1125                       2                    1125
# 12201564             730                     180                     730
# 32738124              28                       4                    1125
# 29516508            1125                       3                    1125
# 20679988             150                       2                    1125
# 30820481            1125                       2                    1125
# 26813241            1125                       2                    1125
# 6953009               25                       1                      25
# 35088121            1125                       1                    1125
# 37628621            1125                       4                       4
# 9384935              120                      30                     120
# 38905198            1125                       1                    1125
# 24371533            1124                       4                       4
# 40929961            1125                       3                    1125
# 37751583             366                       5                     366
# 29794929            1125                       2                    1125
# 22582564              31                       2                      31
# 26029969              30                       5                      30
# 16742255            1125                       2                    1125
# 15216905            1125                       6                    1125
# 42142600            1125                       1                    1125
# 40841455             180                       7                     180
# 42948512              31                       2                    1125
# 22567457              30                       2                      30
# 23455723              18                       4                    1125
# 42076541              30                       4                      30
# 32741575              25                       3                      25
# 30771810            1125                       2                    1125
# 38192212            1125                       2                    1125
#
#           availability_30  availability_365  number_of_reviews  \
# id
# 34840808               27               162                 12
# 17859080               28               315                 49
# 12201564                0                21                  0
# 32738124                0                90                 18
# 29516508               29               100                 98
# 20679988               29               192                 76
# 30820481               28               313                 11
# 26813241               17               146                 34
# 6953009                 0                 0                247
# 35088121               25               265                  9
# 37628621               30               338                  3
# 9384935                29               338                 11
# 38905198               22               172                  0
# 24371533               23                27                 10
# 40929961               30               304                  2
# 37751583                0               309                  7
# 29794929                0                 0                  0
# 22582564                0               259                 64
# 26029969               29               359                 41
# 16742255               30               130                169
# 15216905               22               357                 11
# 42142600                0               270                  8
# 40841455               20               355                  7
# 42948512               19                49                  0
# 22567457               26               358                 18
# 23455723               29               269                 25
# 42076541                0               116                  0
# 32741575                0                50                 81
# 30771810               30                83                 92
# 38192212               27                36                 17
#
#           number_of_reviews_ltm  CTA
# id
# 34840808                     12    3
# 17859080                     20    3
# 12201564                      0   29
# 32738124                     18    4
# 29516508                     76    2
# 20679988                     27    3
# 30820481                     10    3
# 26813241                     15    3
# 6953009                      38    2
# 35088121                      9    1
# 37628621                      3    9
# 9384935                       2    5
# 38905198                      0    1
# 24371533                     10    4
# 40929961                      2   17
# 37751583                      7    4
# 29794929                      0    0
# 22582564                     27   26
# 26029969                     18    4
# 16742255                     55   17
# 15216905                      5    3
# 42142600                      8    2
# 40841455                      7    0
# 42948512                      0   15
# 22567457                      9   12
# 23455723                      8    2
# 42076541                      0    2
# 32741575                     73    4
# 30771810                     69    2
# 38192212                     17    2

# %%
pois_subway.data

# %%
coordinates = [[pois_subway.data.iloc[-1].longitude,pois_subway.data.iloc[-1].latitude]]
for x in range (len(pois_subway.temp[pois_subway.temp['subway'] == 'yes'].dropna(axis=1, how='any'))):
    loc_str = str(pois_subway.temp[pois_subway.temp['subway'] == 'yes'].dropna(axis=1, how='any').geometry.iloc[x])
    loc_num = re.sub("[^0-9,^.,^ ,-]", "", loc_str).lstrip().split(' ')
    for i in range(len(loc_num)): 
        loc_num[i] = float(loc_num[i]) 
    coordinates.append(loc_num)
coordinates
# Out:
# [[-87.68051, 41.91238],
#  [-87.6870645, 41.9159812],
#  [-87.6776609, 41.9098778],
#  [-87.6772433, 41.9096328],
#  [-87.6870338, 41.9160063]]

# %%
coordinates

# %%
matrix = client.distance_matrix(
    locations = coordinates,
    destinations = [_ for _ in range(1,len(coordinates))],
    profile = 'foot-walking',
    metrics = ['distance', 'duration'],
    validate = False,
)
print("Durations in secs: {}\n".format(matrix['durations'][0]))
print("Distances in m: {}".format(matrix['distances'][0]))

# %%
matrix

# %%
matrix['durations'][0].index(min(matrix['durations'][0]))

# %%
matrix['durations'][0][matrix['durations'][0].index(min(matrix['durations'][0]))]

# %%
_ =

# %%
sample = data.sample(10)

# %%
sample

# %%
def pois_subway(data):
    '''
    Returns a new extended dataset with the number of subway (in case of Chicago CTA) 
    stations within a radius of 1000 meters as well as the walking time to the nearest one in seconds.
    If there are not any stations in the radius of 1000m, the walking time to a station within a radius of 5000m is checked.  
    '''
       
    tags = {'railway': 'subway'}
    cta = []
    walk_time = [] #walking time to the closest CTA station in seconds 
    data_temp = data
    for x in range(len(data_temp)):
        print('iteration #:' + ' ' + x)
        pois_temp = ox.pois_from_point(point=(data_temp.latitude.iloc[x],data_temp.longitude.iloc[x]), dist=1000, tags=tags)  
        if 'subway' in pois_temp: # if there is a column 'subway' in the temporary dataset with POIs for a listing x it means that there are stations within 1000m
            train = pois_temp[pois_temp['subway'] == 'yes'].dropna(axis=1, how='any') # slicing out the information about the subways stations (name and location)
            cta.append((len(train['name'].unique()))) # adding the number of unique CTA stations (.unique because several entrences to the same station are recorded)
            coordinates = [[data_temp.iloc[x].longitude,data_temp.iloc[x].latitude]] # extracting the long and lat of a listing x 
            '''
            The following function uses regular expressions (import re) to format the long and lat 
            retrieved by the ox.pois_from_point method. It drops all the symbols that are not a number (^0-9), not a dot (^.), not a space (^ ), and not a negative sign (^-) 
            ''' 
            for x in range (len(train)):
                loc_str = str(train.geometry.iloc[x])
                loc_num = re.sub("[^0-9,^.,^ ,-]", "", loc_str).lstrip().split(' ')
                for i in range(len(loc_num)): 
                    loc_num[i] = float(loc_num[i]) 
                coordinates.append(loc_num)
            '''
            Read more about the OpenRouteService in their docs: https://openrouteservice-py.readthedocs.io/en/latest/ 
            locations - a dicitonary with the pairs of long and lat (includes both the starting point and destination(s))
            destinations - a list of indecies of point to which the distance is going to be measured (basicly just excludes the starting point)
            profile - method of moving (some of the alternatives are “driving-car” and  “cycling-regular”)
            metrics - 'duration': time in secodnds to destination
               also - 'distance': distance in meters  
            
            '''
            matrix = client.distance_matrix(
                locations = coordinates,
                destinations = [_ for _ in range(1,len(coordinates))],
                profile = 'foot-walking',
                metrics = ['duration'],
                validate = False,
            )
            walk_time.append(matrix['durations'][0][matrix['durations'][0].index(min(matrix['durations'][0]))])
        else:
            cta.append(np.nan) 
            pois_temp = ox.pois_from_point(point=(data_temp.latitude.iloc[x],data_temp.longitude.iloc[x]), dist=5000, tags=tags)  
            train = pois_temp[pois_temp['subway'] == 'yes'].dropna(axis=1, how='any')
            coordinates = [[data_temp.iloc[x].longitude,data_temp.iloc[x].latitude]]
            for x in range (len(train)):
                loc_str = str(train.geometry.iloc[x])
                loc_num = re.sub("[^0-9,^.,^ ,-]", "", loc_str).lstrip().split(' ')
                for i in range(len(loc_num)): 
                    loc_num[i] = float(loc_num[i]) 
            coordinates.append(loc_num)
            matrix = client.distance_matrix(
                locations = coordinates,
                destinations = [_ for _ in range(1,len(coordinates))],
                profile = 'foot-walking',
                metrics = ['distance', 'duration'],
                validate = False,
            )
            walk_time.append((matrix['durations'][0][matrix['durations'][0].index(min(matrix['durations'][0]))]))
    data_temp['cta'] = cta
    data_temp['time_to_cta'] = walk_time
    data_cta = data_temp
    return data_cta

# %%
pois_subway(data)
# Out:
# ---------------------------------------------------------------------------
# ApiError                                  Traceback (most recent call last)
# <ipython-input-40-51822ba897d6> in <module>
# ----> 1 pois_subway(data)
#
# <ipython-input-37-fa6ba62489bc> in pois_subway(data)
#      35
#      36             '''
# ---> 37             matrix = client.distance_matrix(
#      38                 locations = coordinates,
#      39                 destinations = [_ for _ in range(1,len(coordinates))],
#
# ~\Anaconda3\envs\ox\lib\site-packages\openrouteservice\client.py in wrapper(*args, **kwargs)
#     287     def wrapper(*args, **kwargs):
#     288         args[0]._extra_params = kwargs.pop("extra_params", None)
# --> 289         result = func(*args, **kwargs)
#     290         try:
#     291             del args[0]._extra_params
#
# ~\Anaconda3\envs\ox\lib\site-packages\openrouteservice\distance_matrix.py in distance_matrix(client, locations, profile, sources, destinations, metrics, resolve_locations, units, optimized, validate, dry_run)
#     119         params["optimized"] = optimized
#     120
# --> 121     return client.request("/v2/matrix/" + profile + '/json', {}, post_json=params, dry_run=dry_run)
#
# ~\Anaconda3\envs\ox\lib\site-packages\openrouteservice\client.py in request(self, url, get_params, first_request_time, retry_counter, requests_kwargs, post_json, dry_run)
#     204
#     205         try:
# --> 206             result = self._get_body(response)
#     207
#     208             return result
#
# ~\Anaconda3\envs\ox\lib\site-packages\openrouteservice\client.py in _get_body(self, response)
#     235             )
#     236         if status_code != 200:
# --> 237             raise exceptions.ApiError(
#     238                 status_code,
#     239                 body
#
# ApiError: 400 ({'error': {'code': 6003, 'message': "Parameter 'locations' has incorrect value or format."}, 'info': {'engine': {'version': '6.1.1', 'build_date': '2020-06-18T15:14:48Z'}, 'timestamp': 1594935400372}})
